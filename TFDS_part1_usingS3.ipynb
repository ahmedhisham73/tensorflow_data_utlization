# %%
try:
    # %tensorflow_version 2.x
except:
    pass

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

print("\u2022 Using TensorFlow Version:", tf.__version__)
# Out:
# • Using TensorFlow Version: 2.6.0

# %%
data, info = tfds.load("rock_paper_scissors", with_info=True)
print(info)
# Out:
# Downloading and preparing dataset rock_paper_scissors/3.0.0 (download: 219.53 MiB, generated: Unknown size, total: 219.53 MiB) to /root/tensorflow_datasets/rock_paper_scissors/3.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/rock_paper_scissors/3.0.0.incomplete6D36XI/rock_paper_scissors-train.tfrecord
#   0%|          | 0/2520 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/rock_paper_scissors/3.0.0.incomplete6D36XI/rock_paper_scissors-test.tfrecord
#   0%|          | 0/372 [00:00<?, ? examples/s]
# Dataset rock_paper_scissors downloaded and prepared to /root/tensorflow_datasets/rock_paper_scissors/3.0.0. Subsequent calls will reuse this data.
# tfds.core.DatasetInfo(
#     name='rock_paper_scissors',
#     version=3.0.0,
#     description='Images of hands playing rock, paper, scissor game.',
#     homepage='http://laurencemoroney.com/rock-paper-scissors-dataset',
#     features=FeaturesDict({
#         'image': Image(shape=(300, 300, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=3),
#     }),
#     total_num_examples=2892,
#     splits={
#         'test': 372,
#         'train': 2520,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""@ONLINE {rps,
#     author = "Laurence Moroney",
#     title = "Rock, Paper, Scissors Dataset",
#     month = "feb",
#     year = "2019",
#     url = "http://laurencemoroney.com/rock-paper-scissors-dataset"
#     }""",
#     redistribution_info=,
# )

# %%
for set in data:
  print(set,":", info.splits[set].num_examples)
# Out:
# test : 372
# train : 2520

# %%
rps_builder =tfds.builder("rock_paper_scissors:3.*.*")

# %%
print(rps_builder.version.implements(tfds.core.Experiment.S3))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-535f9eac5f08> in <module>()
# ----> 1 print(rps_builder.version.implements(tfds.core.Experiment.S3))
#
# /usr/lib/python3.7/enum.py in __getattr__(cls, name)
#     352             return cls._member_map_[name]
#     353         except KeyError:
# --> 354             raise AttributeError(name) from None
#     355
#     356     def __getitem__(cls, name):
#
# AttributeError: S3

# %%
# EXERCISE: In the space below, create two small datasets, `small_train`
# and `small_test`, each of which are comprised of the first 10% of the
# records in their respective datasets.

# YOUR CODE HERE (Include the following arguments in your code: "rock_paper_scissors:3.*.*")
small_train = tfds.load("rock_paper_scissors:3.*.*", split='train[:10%]')

# YOUR CODE HERE (Include the following arguments in your code: "rock_paper_scissors:3.*.*")
small_test = tfds.load("rock_paper_scissors:3.*.*", split='test[:10%]')

# %%
print(len(list(small_train)))

# YOUR CODE HERE)
print(len(list(small_test)))
# Out:
# 252
# 37

# %%
new_train = tfds.load("rock_paper_scissors:3.*.*", split='train[:90%]')
print(len(list(new_train)))

# YOUR CODE HERE (Include the following arguments in your code: "rock_paper_scissors:3.*.*")

new_test = tfds.load("rock_paper_scissors:3.*.*", split='test[:90%]')
print(len(list(new_test)))

# YOUR CODE HERE (Include the following arguments in your code: "rock_paper_scissors:3.*.*")
validation = tfds.load("rock_paper_scissors:3.*.*", split='train[90%:] + test[90%:]')
print(len(list(validation)))
# Out:
# 2268
# 335
# 289
